# %% [markdown]
# # `pyroomacoustics` demo
#
# In this IPython notebook, we demonstrate a few features of `pyroomacoustics`:
#
# 1. Its _pythonic_ and convenient object-oriented interface.
# 2. The Room Impulse Response (RIR) generator.
# 3. Provided reference algorithms.
#
# Below is a list of the examples (run all cells as some may depend on previous imports and results).
#
# 1. [Creating a 2D/3D room](#room)
# 2. [Adding sources and microphones](#source_mic)
# 3. [Room Impulse Response generation and propagation simulation](#rir)
# 4. [Beamforming](#bf)
# 5. [Direction-of-arrival](#doa)
# 6. [Adaptive filtering](#af)
# 7. [STFT processing](#stft)
# 8. [Source Separation](#bss)
#
# More information on the package can be found on the [Github repo](https://github.com/LCAV/pyroomacoustics) and from the [paper](https://arxiv.org/pdf/1710.04196.pdf), which can be cited as:
#
# _R. Scheibler, E. Bezzam, I. Dokmanić, Pyroomacoustics: A Python package for audio room simulations and array processing algorithms, Proc. IEEE ICASSP, Calgary, CA, 2018._
#
# Let's begin by importing the necessary libraries all of which can be installed with `pip`, even `pyroomacoustics`!

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile
from scipy.signal import fftconvolve
import IPython
import pyroomacoustics as pra
import scipy.signal as signal

# %% [markdown]
# <a id='doa'></a>
# ## Direction of Arrival
#
# Several reference algorithms for direction-of-arrival (DOA) estimation are provided. These methods work in the frequency domain of which there are generally two types: incoherent and coherent methods.
#
# We provide the following algorithms: SRP-PHAT, MUSIC, CSSM, WAVES, TOPS, and FRIDA.
#
# Let's perform DOA for two sources.

# %%
# Location of sources
azimuth = np.array([165.]) / 180. * np.pi
distance = 2.  # meters

# %% [markdown]
# A few constants and parameters for the algorithm such as the FFT size and the frequency range over which to perform DOA.

# %%
c = 343.    # speed of sound
fs = 96000  # sampling frequency
nfft = 256  # FFT size
freq_range = [30000, 50000]

# %% [markdown]
# Let's build a 2D room where we will perform our simulation.

# %%
snr_db = 5.    # signal-to-noise ratio
sigma2 = 10**(-snr_db / 10) / (4. * np.pi * distance)**2

# Create an anechoic room
room_dim = np.r_[5.,5.]
aroom = pra.ShoeBox(room_dim, fs=fs, max_order=0, sigma2_awgn=sigma2)

fig, ax = aroom.plot()
ax.set_xlim([-1, room_dim[0]+1])
ax.set_ylim([-1, room_dim[1]+1])
# Out:
# (-1.0, 6.0)

# %%
echo = pra.linear_2D_array(center=room_dim/2, M=5, phi=0, d=0.003)
echo = np.concatenate((echo, np.array(room_dim/2, ndmin=2).T), axis=1)
aroom.add_microphone_array(pra.MicrophoneArray(echo, aroom.fs))

fig = plt.figure(figsize=(20, 8))
fig, ax = aroom.plot()

ax.set_xlim([-1, room_dim[0]+1]);
ax.set_ylim([-1, room_dim[1]+1]);

# %%
tone_durn = 2000e-3 # seconds
t_tone = np.linspace(0, tone_durn, int(fs*tone_durn))
chirp = signal.chirp(t_tone, 35e3, t_tone[-1], 45e3)
chirp *= signal.windows.hann(chirp.size)
output_chirp = np.concatenate((chirp, np.zeros((int(fs*0.2)))))

# %% [markdown]
# We'll create two synthetic signals and add them to the room at the specified locations with respect to the array.

# %%
# Add sources of 1 second duration
rng = np.random.RandomState(23)
duration_samples = int(fs)

for ang in azimuth:
    source_location = room_dim/2  + distance * np.r_[np.cos(ang), np.sin(ang)]
    source_signal = output_chirp
    aroom.add_source(source_location, signal=source_signal)
    
# Run the simulation
aroom.simulate()

IPython.display.Audio(data=source_signal, rate=fs)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fig, ax = aroom.plot()

ax.set_xlim([-1, room_dim[0]+1]);
ax.set_ylim([-1, room_dim[1]+1]);

# %% [markdown]
# The DOA algorithms require an STFT input, which we will compute for overlapping frames for our 1 second duration signal.

# %%
X = pra.transform.stft.analysis(aroom.mic_array.signals.T, nfft, nfft // 2)
X = X.transpose([2, 1, 0])

# %% [markdown]
# Now let's compare a few algorithms!

# %%
algo_names = ['SRP', 'MUSIC', 'FRIDA', 'TOPS']
spatial_resp = dict()

# loop through algos
for algo_name in algo_names:
    # Construct the new DOA object
    # the max_four parameter is necessary for FRIDA only
    doa = pra.doa.algorithms[algo_name](echo, fs, nfft, c=c, num_src=2, max_four=4)

    # this call here perform localization on the frames in X
    doa.locate_sources(X, freq_range=freq_range)
    
    # store spatial response
    if algo_name is 'FRIDA':
        spatial_resp[algo_name] = np.abs(doa._gen_dirty_img())
    else:
        spatial_resp[algo_name] = doa.grid.values
        
    # normalize   
    min_val = spatial_resp[algo_name].min()
    max_val = spatial_resp[algo_name].max()
    spatial_resp[algo_name] = (spatial_resp[algo_name] - min_val) / (max_val - min_val)
# Out:
# <>:14: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# <>:14: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
# /var/folders/pc/w8yjxfyn7g93139kxqngkny00000gn/T/ipykernel_6084/95203986.py:14: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if algo_name is 'FRIDA':
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=2.02747e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.12879e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.25291e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.78909e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.99344e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.23658e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=2.74364e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.44984e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.21049e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.80198e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.73152e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=2.12913e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.13258e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=2.15296e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.23866e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=7.29311e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.12719e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=5.35763e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.64704e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.34426e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.94336e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.5994e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=3.59136e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=5.18268e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=8.83691e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=3.72254e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=5.17481e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=2.49544e-21): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=5.29647e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=5.73692e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=8.60528e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.0103e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.54037e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=9.08454e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.19769e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=3.68636e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.7384e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.36905e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.41389e-21): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.26421e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=2.1351e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=3.43962e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.15053e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.69832e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.12564e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=3.52491e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=1.64671e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.0832e-20): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1121: LinAlgWarning: Ill-conditioned matrix (rcond=4.13476e-19): result may not be accurate.
#   linalg.solve(np.dot(Rc0, np.dot(GtG_inv_lst[loop], Rc0.T)), Tbeta_loop),
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.93799e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.36479e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.468e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.58315e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.77319e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.05386e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.7878e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.02386e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.66304e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.15199e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.12492e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.63961e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.9423e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.37549e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.09261e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.24276e-21): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.21492e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.46235e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.78691e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.26577e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.77052e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.55974e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.47535e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.64322e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.43192e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.24135e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.64229e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.3288e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.93865e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.95232e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.63783e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.5504e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.56528e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.03033e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.76457e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.20039e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.55032e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.74757e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.19492e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.42153e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.44848e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.12616e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=7.84062e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.64804e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.72236e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.11784e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.75605e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.37765e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.0876e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.10787e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.17919e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.48373e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.15352e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.11073e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.16773e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.9475e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.93271e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.8034e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.69678e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.69178e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.3433e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.0535e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.72977e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.56627e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.5971e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.51633e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.09113e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.45839e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.46263e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.55474e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.41909e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.86439e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.32871e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.03253e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.65744e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.7112e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.96642e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.11664e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.55609e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.59236e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.70095e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.44392e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.74638e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.79716e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.66102e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.34316e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.51635e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.03788e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.01707e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.60849e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.15542e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.11978e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.40449e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.20388e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.25005e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.32918e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=9.19009e-21): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.54205e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.79364e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.88058e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.30635e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.52976e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.1678e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.92495e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.99421e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.63369e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.55178e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.13798e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.5373e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.16331e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.20635e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.26081e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=7.61879e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.66893e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.96508e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.71565e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.95705e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.25974e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.05766e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.3802e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.11574e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.08923e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.57662e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.17167e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.25554e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.69938e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=7.10536e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.3698e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.20757e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.63138e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.79057e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.56012e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.94066e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.21009e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.96735e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.08462e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.38076e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.92839e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.53153e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=7.36326e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.85396e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.03639e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.05464e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.94446e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.61245e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.10304e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.97313e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.39599e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=9.66892e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.2638e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.11219e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.22298e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.47338e-21): result may not be accurate.
# ...
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.02832e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.06425e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.15766e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.17604e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.44611e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.25575e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.08679e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.89487e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.50653e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.37795e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.49261e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.96612e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.12668e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.52685e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.24055e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.1103e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.76144e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=9.7632e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.38702e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.27642e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.3724e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.67856e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.3396e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.67618e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.55386e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.39052e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.74719e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.0757e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=6.74435e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.31101e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=9.32739e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.58902e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.22742e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.0621e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.16143e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=7.80437e-21): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.38127e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.50306e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.26186e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.68376e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.82532e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=9.46835e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.60606e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.07221e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.6351e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.52896e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.58925e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.46165e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.58878e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.37581e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=7.47279e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.81517e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=7.94055e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.8407e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.50296e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.13836e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.63249e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.2357e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.44732e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=4.42655e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.36385e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.1013e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.94696e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.11911e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.44938e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=8.14907e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.01302e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=2.93612e-19): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.16608e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=1.5113e-18): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=5.9953e-20): result may not be accurate.
#   linalg.solve(
# /Users/alberto/anaconda3/envs/Tesipython/lib/python3.12/site-packages/pyroomacoustics/doa/tools_fri_doa_plane.py:1169: LinAlgWarning: Ill-conditioned matrix (rcond=3.11844e-19): result may not be accurate.
#   linalg.solve(

# %% [markdown]
# Let's plot the estimated spatial spectra and compare it with the true locations!

# %%
# plotting param
base = 1.
height = 10.
true_col = [0, 0, 0]

# loop through algos
phi_plt = doa.grid.azimuth
for algo_name in algo_names:
    # plot
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='polar')
    c_phi_plt = np.r_[phi_plt, phi_plt[0]]
    c_dirty_img = np.r_[spatial_resp[algo_name], spatial_resp[algo_name][0]]
    ax.plot(c_phi_plt, base + height * c_dirty_img, linewidth=3,
            alpha=0.55, linestyle='-',
            label="spatial spectrum")
    plt.title(algo_name)
    
    # plot true loc
    for angle in azimuth:
        ax.plot([angle, angle], [base, base + height], linewidth=3, linestyle='--',
            color=true_col, alpha=0.6)
    K = len(azimuth)
    ax.scatter(azimuth, base + height*np.ones(K), c=np.tile(true_col,
               (K, 1)), s=500, alpha=0.75, marker='*',
               linewidths=0,
               label='true locations')

    plt.legend()
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles, labels, framealpha=0.5,
              scatterpoints=1, loc='center right', fontsize=16,
              ncol=1, bbox_to_anchor=(1.6, 0.5),
              handletextpad=.2, columnspacing=1.7, labelspacing=0.1)

    ax.set_xticks(np.linspace(0, 2 * np.pi, num=12, endpoint=False))
    ax.xaxis.set_label_coords(0.5, -0.11)
    ax.set_yticks(np.linspace(0, 1, 2))
    # ax.xaxis.grid(b=True, color=[0.3, 0.3, 0.3], linestyle=':')
    # ax.yaxis.grid(b=True, color=[0.3, 0.3, 0.3], linestyle='--')
    ax.set_ylim([0, 1.05 * (base + height)])
    
plt.show()
